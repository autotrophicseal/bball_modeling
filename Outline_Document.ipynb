# %% [markdown]
# # Sports
#
# Of the many sports that I can bet on, I am going to bet only on NCAAB. I am going to start with MSU basketball, as this is a team I regularly follow and am able to watch in person and spend time analyzing it. If I find this is not enough to keep me occupied, I will look to Tennesse and Purdue to track as well. Purdue utilizes a vastly different approach to basketball than both Tennessee and MSU do which makes them an interesting one if I want to try something different. Quick recap:
#
# 1. MSU
# 2. Tennessee
# 3. Purdue

# %% [markdown]
# # Common Predictions in Basketball Betting
#
# In basketball betting, there are several common events or items that people try to predict. Let's explore some of these predictions:
#
# ## Game Outcome Predictions:
#
# - Predicting if Michigan State will win the game outright.
# - Predicting if Michigan State will cover the point spread (e.g., -14.5 points) or if the underdog (James Madison) will cover it.
# - Betting on the over/under total points scored in the game.
#
# *TOO VAGUE... SO MANY FACTORS CAN GO INTO THIS
#
# ## Player Performance Predictions:
#
# - Predicting the total points scored by a specific Michigan State player in the game.
# - Predicting the total rebounds, assists, or steals by a particular player.
# - Betting on whether a player will achieve a double-double (e.g., points and rebounds) or a triple-double (points, rebounds, and assists).
# - Betting on which player will be the highest scorer in the game.
#
# *WITH MY CURRENT KNOWLEDGE, THIS IS COMPLETELY RANDOM... EXTREMELY DIFFICULT TO PREDICT INDIVIDUALS
#
# ## Team Performance Predictions:
#
# - Predicting the total number of three-pointers made by Michigan State as a team.
# - Betting on which team will have the most rebounds or assists in the game.
# - Predicting if Michigan State will lead at halftime and win the game.
#
# *PROBABLY THE BETTER OF ALL THESE TO TRY AND PREDICT. RIGHT IN THE SWEET SPOT
#
# ## Quarter/Half Predictions:
#
# - Predicting the winner of a specific quarter or half of the game.
# - Betting on the total points scored in a particular quarter or half.
#
# *THIS IS STUPID. VIRTUALLY IMPOSSIBLE TO PREDICT
#
# ## Prop Bets:
#
# - These are novelty bets that cover a wide range of events within the game. For example, you can bet on things like the first team to score, the first player to make a three-pointer, or the exact margin of victory.
#
# *STUPID AND NOVELTY SHIT. COMPLETELY RANDOM AND NOT WORTH THINKING ABOUT
#
# ## Live Betting:
#
# - Betting on various in-game events as they happen, such as which team will score next or how many points will be scored in a specific time frame.
#
# *ABSOLUTELY NOT. AGAIN... COMPLETELY RANDOM
#
# ## Parlays and Teasers:
#
# - Combining multiple bets into a single wager for a higher potential payout. For instance, you could bet on the game outcome, the total points, and a player's performance all in one bet.
#
# *SOMETHING THAT WOULD HAPPEN LATER IF I START TO UNDERSTAND BASIC TRENDS
#
# ## Futures Betting:
#
# - Predicting events that will occur in the future, like which team will win the championship at the end of the season.
#
# *NO
#
# These are just a few examples of the many betting options available in sports betting. Keep in mind that the availability of specific bets and the odds associated with them can vary from sportsbook to sportsbook, and it's important to understand the odds and the game to make informed predictions and bets.

# %% [markdown]
# # What will I pay attention to?
#
# As explained above, there are a lot of different options to choose from to focus in on. I am looking for something that focuses in on the gameplay of the game. I want to understand the relationships between the players on the field from both sides. I want to understand how previous games and previous stat's can help predict how individuals will do on the field. This will lead me to (hopefully) a better understanding of what makes a game swing one way vs the other. However, focusing too narrow will result in the inability to accuractely predict anything. It's virtually impossible to predict how a single individual will act. However, we can predict large groups of people with unbelievable certainty. As a result I will be focusing on the following.
#
# ## Team performance Predictions
#
# The following are the most realistic Team performance items that I may be able to predict.
#
# 1. Predicting the number of 3 pointers the team will make
# 2. Who will have the most rebounds
# 3. Who will have the most assists
# 4. Total Points scored
# 5. Team Steals
# 6. Team Blocks
# 7. Team Turnovers
#
# I am not completely sure as to which one of these are the easiest to predict. Chat GPT seems to think that they are all reasonable to try and predict with the exception of Team Blocks and Steals.
#
# Below is the result of GPT's quick synopsis of the team performance predictions and their predictors (very high overview)

# %% [markdown]
# # Predictability of Basketball Game Events
#
# In basketball betting, predicting game events with a high degree of certainty can vary based on several factors. Let's evaluate some common game events and the factors that can help in making more accurate predictions. The green checkmark indicates what I will be going with. More of a random choice than anything...
#
# ## 1. Predicting the Number of 3-Pointers the Team Will Make:<span style="color: green; font-size: 50px;">&#10004;</span>
#
# - **Easiness to Predict:** Moderate
# - **Factors:**
#   - Team Averages: You can look at a team's historical performance and average number of 3-pointers made per game.
#   - Opponent Defense: Assess the opponent's 3-point defense.
#   - Player Injuries: The availability of key 3-point shooters.
#
# ## 2. Who Will Have the Most Rebounds:
#
# - **Easiness to Predict:** Moderate
# - **Factors:**
#   - Player Averages: Study the rebounding statistics of individual players.
#   - Matchup: Consider the size and style of play of the opposing teams.
#   - Game Situation: The pace of the game and missed shots.
#
# ## 3. Who Will Have the Most Assists:
#
# - **Easiness to Predict:** Moderate
# - **Factors:**
#   - Point Guard Performance: The team's primary playmaker.
#   - Offensive Style: Teams with a fast-paced, ball-sharing offense.
#   - Opposition Defense: Defensive schemes.
#
# ## 4. Total Points Scored:
#
# - **Easiness to Predict:** Moderate
# - **Factors:**
#   - Team Scoring Averages: Each team's scoring averages.
#   - Pace of Play: Game tempo.
#   - Defensive Strength: Defensive abilities.
#
# ## 5. Team Steals:
#
# - **Easiness to Predict:** Difficult
# - **Factors:**
#   - Defensive Strategy: Aggressive, ball-hawking defenses.
#   - Opponent Turnovers: Opponent's turnover tendencies.
#   - Player Skills: Individual players with stealing ability.
#
# ## 6. Team Blocks:
#
# - **Easiness to Predict:** Moderate
# - **Factors:**
#   - Shot-Blocking Players: Teams with strong shot-blockers.
#   - Opponent Shot Attempts: Attempt locations.
#   - Defensive Schemes: Focus on rim protection.
#
# ## 7. Team Turnovers:
#
# - **Easiness to Predict:** Moderate
# - **Factors:**
#   - Ball-Handling Skills: Skilled ball-handlers and decision-making.
#   - Defensive Pressure: Intense defensive pressure.
#   - Turnover Averages: Team and opponent averages.
#
# In general, predicting any of these basketball game events with a high degree of certainty can be challenging. Consider the provided factors to increase your chances of making more accurate predictions.

# %% [markdown]
# Next steps. Find Data

# %% [markdown]
# Stats Perform - not for me
# Sportradar - Not for me
# ncaa seems to be the spot

# %% [markdown]
# ## Approach?
#
# Seems that probabelistic approaches to guessing match numbers has reached a plateau. Machine learning appears to be the best approach.
