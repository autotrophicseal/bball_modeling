# %%
import pandas as pd

# %%
# Load Data
table = pd.read_csv("2017_teams.csv")
# Replace index
table.index = table['School']
table = table.drop(columns = ['School', 'Rk'])
# Remove NCAA from index
table.index = table.index.str.replace(" NCAA", "", regex=True)
table
# Out:
#                     G   W   L   W-L%    SRS    SOS  W.1  L.1  W.2  L.2  ...  \
# School                                                                  ...
# Abilene Christian  29  13  16  0.448 -11.86  -7.10    7   11    9    5  ...
# Air Force          33  12  21  0.364  -3.06   1.00    4   14   11    7  ...
# Akron              36  27   9  0.750   3.59  -1.21   14    4   13    2  ...
# Alabama            34  19  15  0.559  11.29   7.47   10    8   11    6  ...
# Alabama A&M        29   2  27  0.069 -26.99 -11.09    2   16    1    9  ...
# ...                ..  ..  ..    ...    ...    ...  ...  ...  ...  ...  ...
# Wright State       32  20  12  0.625  -1.02  -2.42   11    7   12    4  ...
# Wyoming            38  23  15  0.605   2.83   0.55    8   10   19    3  ...
# Xavier             38  24  14  0.632  14.80  11.51    9    9   12    4  ...
# Yale               29  18  11  0.621   0.21  -2.19    9    5   10    3  ...
# ...

# %%
table.to_csv("teams.csv", index=True)

# %%
table.loc["Michigan State"]
# Out:
# G         35.000
# W         20.000
# L         15.000
# W-L%       0.571
# SRS       13.670
# SOS       10.500
# W.1       10.000
# L.1        8.000
# W.2       14.000
# L.2        2.000
# W.3        2.000
# L.3        7.000
# Tm.     2515.000
# Opp.    2404.000
# MP      1405.000
# FG       905.000
# FGA     1927.000
# FG%        0.470
# 3P       273.000
# 3PA      732.000
# 3P%        0.373
# FT       432.000
# FTA      646.000
# FT%        0.669
# ORB      328.000
# TRB     1275.000
# AST      591.000
# STL      151.000
# BLK      162.000
# TOV      490.000
# PF       699.000
# Name: Michigan State, dtype: float64
